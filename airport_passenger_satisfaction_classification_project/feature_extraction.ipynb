# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.preprocessing import MinMaxScaler,LabelEncoder

# %%
data_train=pd.read_csv("data/train.csv")
data_test=pd.read_csv("data/test.csv")

# %%
data_train.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data_train["is_train"]=1
data_test["is_train"]=0
df=pd.concat([data_train,data_test],ignore_index=True)

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  On-board service  Leg room service  \
# 0                                  4  ...                 4                 3
# ...

# %%
df.drop(columns={"Unnamed: 0","id"},axis=1,inplace=True)

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  On-board service  \
# 0                       3              1  ...                 4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
# ...

# %%
df.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %%
df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# ...

# %%
df.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# ...

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean())
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  On-board service  \
# 0                       3              1  ...                 4
# ...

# %%
categorical_data=df.nunique() ==2
col=df.columns[categorical_data]
col
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'satisfaction',
#        'is_train'],
#       dtype='object')

# %%
label_encoder=LabelEncoder()
for i in range(4):
    df[col[i]]=label_encoder.fit_transform(df[col[i]])

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel     Class  Flight Distance  \
# 0       1              0   13               1  Eco Plus              460
# 1       1              1   25               0  Business              235
# 2       0              0   26               0  Business             1142
# 3       0              0   25               0  Business              562
# 4       1              0   61               0  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  On-board service  \
# 0                       3              1  ...                 4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  int64
#  1   Customer Type                      129880 non-null  int64
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  int64
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
# ...

# %%
df.shape
# Out:
# (129880, 24)

# %%
df=pd.get_dummies(df,columns=["Class"])

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0       1              0   13               1              460
# 1       1              1   25               0              235
# 2       0              0   26               0             1142
# 3       0              0   25               0              562
# 4       1              0   61               0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  ...  \
# 0                       3              1               5  ...
# 1                       3              3               1  ...
# ...

# %%
df.dtypes
# Out:
# Gender                                 int64
# Customer Type                          int64
# Age                                    int64
# Type of Travel                         int64
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# ...

# %%
df.nunique()
# Out:
# Gender                                  2
# Customer Type                           2
# Age                                    75
# Type of Travel                          2
# Flight Distance                      3821
# Inflight wifi service                   6
# Departure/Arrival time convenient       6
# Ease of Online booking                  6
# Gate location                           6
# Food and drink                          6
# Online boarding                         6
# Seat comfort                            6
# Inflight entertainment                  6
# On-board service                        6
# Leg room service                        6
# Baggage handling                        5
# Checkin service                         6
# Inflight service                        6
# Cleanliness                             6
# Departure Delay in Minutes            466
# Arrival Delay in Minutes              473
# satisfaction                            2
# ...

# %%
scaler_list=["Age","Flight Distance","Departure Delay in Minutes","Arrival Delay in Minutes"]

# %%
scaler=MinMaxScaler()
df[scaler_list]=scaler.fit_transform(df[scaler_list])

# %%
df.head(10)
# Out:
#    Gender  Customer Type       Age  Type of Travel  Flight Distance  \
# 0       1              0  0.076923               1         0.086632
# 1       1              1  0.230769               0         0.041195
# 2       0              0  0.243590               0         0.224354
# 3       0              0  0.230769               0         0.107229
# 4       1              0  0.692308               0         0.036955
# 5       0              0  0.243590               1         0.232027
# 6       1              0  0.512821               1         0.251414
# 7       0              0  0.576923               0         0.404685
# 8       0              0  0.435897               0         0.165994
# 9       1              1  0.166667               0         0.207997
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# ...

# %%
df.describe()
# Out:
#               Gender  Customer Type            Age  Type of Travel  \
# count  129880.000000  129880.000000  129880.000000   129880.000000
# mean        0.492616       0.183092       0.415743        0.309416
# std         0.499947       0.386743       0.193838        0.462255
# min         0.000000       0.000000       0.000000        0.000000
# 25%         0.000000       0.000000       0.256410        0.000000
# 50%         0.000000       0.000000       0.423077        0.000000
# 75%         1.000000       0.000000       0.564103        1.000000
# max         1.000000       1.000000       1.000000        1.000000
#
#        Flight Distance  Inflight wifi service  \
# count    129880.000000          129880.000000
# mean          0.234111               2.728696
# std           0.201424               1.329340
# min           0.000000               0.000000
# 25%           0.077342               2.000000
# 50%           0.164176               3.000000
# ...

# %%
train_preprocessed=df[df["is_train"]==1]

# %%
test_preprocessed=df[df["is_train"]==0]

# %%
test_preprocessed.head()
# Out:
#         Gender  Customer Type       Age  Type of Travel  Flight Distance  \
# 103904       0              0  0.576923               0         0.026050
# 103905       0              0  0.371795               0         0.571890
# 103906       1              1  0.166667               0         0.032512
# 103907       1              0  0.474359               0         0.675687
# 103908       0              0  0.538462               0         0.232431
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 103904                      5                                  4
# 103905                      1                                  1
# 103906                      2                                  0
# 103907                      0                                  0
# 103908                      2                                  3
#
#         Ease of Online booking  Gate location  Food and drink  ...  \
# ...

# %%
train_preprocessed.to_csv("data/train_preprocessed.csv",index=False)

# %%
test_preprocessed.to_csv("data/test_preprocessed.csv",index=False)
